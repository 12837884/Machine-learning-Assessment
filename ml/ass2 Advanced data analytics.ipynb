# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./Admission_Predict.csv")

# %%
data.head()
# Out:
#    nma  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0    1        337          118                  4  4.5   4.5  9.65         1
# 1    2        324          107                  4  4.0   4.5  8.87         1
# 2    3        316          104                  3  3.0   3.5  8.00         1
# 3    4        322          110                  3  3.5   2.5  8.67         1
# 4    5        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
#set column Serial No. as index
data = data.set_index(data['nma'])
data.drop('nma', axis='columns', inplace=True)

# %%
data = data.rename(columns = {'Chance of Admit ':'CoA','University Rating':'UR','LOR ':'LOR','GRE Score':'GRES','TOEFL Score':'TOEFLS'})
data
# Out:
#      GRES  TOEFLS  UR  SOP  LOR  CGPA  Research   CoA
# nma
# 1     337     118   4  4.5  4.5  9.65         1  0.92
# 2     324     107   4  4.0  4.5  8.87         1  0.76
# 3     316     104   3  3.0  3.5  8.00         1  0.72
# 4     322     110   3  3.5  2.5  8.67         1  0.80
# 5     314     103   2  2.0  3.0  8.21         0  0.65
# ..    ...     ...  ..  ...  ...   ...       ...   ...
# 396   324     110   3  3.5  3.5  9.04         1  0.82
# 397   325     107   3  3.0  3.5  9.11         1  0.84
# 398   330     116   4  5.0  4.5  9.45         1  0.91
# 399   312     103   3  3.5  4.0  8.78         0  0.67
# 400   333     117   4  5.0  4.0  9.66         1  0.95
#
# [400 rows x 8 columns]

# %%
data.describe()
# Out:
#              GRES      TOEFLS          UR         SOP         LOR        CGPA  \
# count  400.000000  400.000000  400.000000  400.000000  400.000000  400.000000
# mean   316.807500  107.410000    3.087500    3.400000    3.452500    8.598925
# std     11.473646    6.069514    1.143728    1.006869    0.898478    0.596317
# min    290.000000   92.000000    1.000000    1.000000    1.000000    6.800000
# 25%    308.000000  103.000000    2.000000    2.500000    3.000000    8.170000
# 50%    317.000000  107.000000    3.000000    3.500000    3.500000    8.610000
# 75%    325.000000  112.000000    4.000000    4.000000    4.000000    9.062500
# max    340.000000  120.000000    5.000000    5.000000    5.000000    9.920000
#
#          Research         CoA
# count  400.000000  400.000000
# mean     0.547500    0.724350
# std      0.498362    0.142609
# min      0.000000    0.340000
# 25%      0.000000    0.640000
# 50%      1.000000    0.730000
# 75%      1.000000    0.830000
# ...

# %%
#data visualization
import matplotlib.pyplot as plt
import seaborn as sns
x = data['GRES']
y = data['CoA']
plt.title('Dot plot of GRES', size=24)
plt.xlabel('GRES', size=18)
plt.ylabel('Chance of Admit', size=18)
plt.scatter(x,y)
plt.show()

# %%
x = data['GRES']
y = data['CoA']
plt.xlabel('GRES')
plt.ylabel('Chance of Admit')
plt.title('Relationship between GRES and CoA variables and the best-fit line')
sns.regplot(x, y)

# %%
x = data['TOEFLS']
y = data['CoA']
plt.title('Dot plot of TOEFLS', size=24)
plt.xlabel('TOEFLS', size=18)
plt.ylabel('Chance of Admit', size=18)
plt.scatter(x,y)
plt.show()

# %%
x = data['TOEFLS']
y = data['CoA']
plt.xlabel('TOEFLS')
plt.ylabel('Chance of Admit')
plt.title('Relationship between TOEFLS and CoA variables and the best-fit line')
sns.regplot(x, y)

# %%
x = data['CGPA']
y = data['CoA']
plt.title('Dot plot of CGPA', size=24)
plt.xlabel('CGPA', size=18)
plt.ylabel('Chance of Admit', size=18)
plt.scatter(x,y)
plt.show()

# %%
x = data['CGPA']
y = data['CoA']
plt.xlabel('CGPA')
plt.ylabel('Chance of Admit')
plt.title('Relationship between CGPA and CoA variables and the best-fit line')
sns.regplot(x, y)

# %%
data.GRES.plot(kind='hist', color='purple', edgecolor='black', figsize=(10,7))
plt.title('Distribution of GRES', size=24)
plt.xlabel('GRES', size=18)
plt.ylabel('Frequency', size=18)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
data.TOEFLS.plot(kind='hist', color='purple', edgecolor='black', figsize=(10,7))
plt.title('Distribution of TOEFLS', size=24)
plt.xlabel('TOEFLS', size=18)
plt.ylabel('Frequency', size=18)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
data.CGPA.plot(kind='hist', color='purple', edgecolor='black', figsize=(10,7))
plt.title('Distribution of CGPA', size=24)
plt.xlabel('CGPA', size=18)
plt.ylabel('Frequency', size=18)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
data.CoA.plot(kind='hist', color='purple', edgecolor='black', figsize=(10,7))
plt.title('Distribution of ChanceOfAdmit', size=24)
plt.xlabel('ChanceOfAdmit', size=18)
plt.ylabel('Frequency', size=18)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x = data['SOP']
y = data['CoA']
plt.title('Dot plot of SOP', size=24)
plt.xlabel('SOP', size=18)
plt.ylabel('Chance of Admit', size=18)
plt.scatter(x,y)
plt.show()

# %%
x = data['UR']
y = data['CoA']
plt.title('Dot plot of UR', size=24)
plt.xlabel('UR', size=18)
plt.ylabel('Chance of Admit', size=18)
plt.scatter(x,y)
plt.show()

# %%
x = data['LOR']
y = data['CoA']
plt.title('Dot plot of LOR', size=24)
plt.xlabel('LOR', size=18)
plt.ylabel('Chance of Admit', size=18)
plt.scatter(x,y)
plt.show()

# %%
x = data['Research']
y = data['CoA']
plt.title('Dot plot of Research', size=24)
plt.xlabel('Research', size=18)
plt.ylabel('Chance of Admit', size=18)
plt.scatter(x,y)
plt.show()

# %%
data = pd.DataFrame(data)
#X = data[['GRES','TOEFLS','UR','SOP','LOR','Research','CGPA']]
X = data[['CGPA']]
Y = data[['CoA']]*100
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.5,random_state=0)

# %%
# make homogenours variable list
one_train=np.ones((len(x_train),1))
x_train_homo = np.c_[one_train,x_train]
one_test=np.ones((len(x_test),1))
x_test_homo = np.c_[one_test,x_test]
x_train_homo
# Out:
# array([[1.  , 9.08],
#        [1.  , 9.17],
#        [1.  , 8.42],
#        [1.  , 7.95],
#        [1.  , 8.49],
#        [1.  , 9.  ],
#        [1.  , 7.89],
#        [1.  , 9.2 ],
#        [1.  , 8.54],
#        [1.  , 9.12],
#        [1.  , 8.64],
#        [1.  , 9.8 ],
#        [1.  , 8.21],
#        [1.  , 9.4 ],
#        [1.  , 8.15],
#        [1.  , 9.35],
#        [1.  , 7.88],
#        [1.  , 8.68],
#        [1.  , 8.33],
#        [1.  , 8.44],
#        [1.  , 8.26],
#        [1.  , 8.24],
#        [1.  , 8.  ],
#        [1.  , 8.8 ],
#        [1.  , 9.66],
#        [1.  , 7.36],
#        [1.  , 8.83],
#        [1.  , 9.23],
#        [1.  , 9.76],
#        [1.  , 8.  ],
#        [1.  , 7.46],
#        [1.  , 9.78],
#        [1.  , 9.82],
#        [1.  , 7.8 ],
#        [1.  , 8.67],
#        [1.  , 7.86],
#        [1.  , 9.05],
#        [1.  , 7.46],
#        [1.  , 9.36],
#        [1.  , 9.08],
#        [1.  , 9.45],
#        [1.  , 7.28],
#        [1.  , 9.12],
# ...

# %%
x_train_homo.shape[1]
# Out:
# 2

# %%
# random initialization of the model weights
m_samples, n_features = x_train_homo.shape
w = np.random.rand(n_features,1)
w
# Out:
# array([[0.2394805 ],
#        [0.35401579]])

# %%
y = np.array(y_train)
x = np.array(x_train_homo)

# %%
training_errors = []
times = 3000
learning_rate = 0.00001
x = x_train_homo
for i in range(times):
    y = np.dot(x,w)
    difference = y-y_train
    loss = np.mean(0.5 * (difference) ** 2) #calculate loss
    #print(loss)
    training_errors.append(loss)
    w_grad = np.dot(x.T,difference)   # (y - y_train).T.dot(X)，calculate the gradient
    w_grad = 2/x_train_homo.shape[0]*w_grad
    #print(w_grad)
    w = w - learning_rate * w_grad #update w
w
# Out:
# array([[1.11519605],
#        [8.25378887]])

# %%
#predict
y_pred = np.dot(x_test_homo,w)
#y_pred = np.reshape(y_pred, y_test.shape)
y_pred
# Out:
# array([[71.76762877],
#        [72.09778032],
#        [73.41838654],
#        [69.29149211],
#        [73.17077288],
#        [67.97088589],
#        [72.84062132],
#        [67.888348  ],
#        [78.37065986],
#        [78.8658872 ],
#        [65.49474923],
#        [77.71035675],
#        [71.76762877],
#        [60.95516535],
#        [76.22467476],
#        [69.62164366],
#        [68.631189  ],
#        [76.6373642 ],
#        [66.23759023],
#        [72.84062132],
#        [76.71990209],
#        [76.55482631],
#        [71.02478777],
#        [61.69800635],
#        [74.32630332],
#        [67.47565856],
#        [63.34876412],
#        [69.62164366],
#        [76.96751576],
#        [69.20895422],
#        [67.47565856],
#        [71.68509088],
#        [72.51046977],
#        [67.39312067],
#        [74.73899276],
#        [73.08823499],
#        [66.48520389],
#        [77.29766731],
#        [69.37403   ],
#        [80.84679652],
#        [70.94224988],
# ...

# %%
training_errors
# Out:
# [CoA    2493.781816
#  dtype: float64,
#  CoA    2486.421918
#  dtype: float64,
#  CoA    2479.084241
#  dtype: float64,
#  CoA    2471.768717
#  dtype: float64,
#  CoA    2464.475278
#  dtype: float64,
#  CoA    2457.203859
#  dtype: float64,
#  CoA    2449.954393
#  dtype: float64,
#  CoA    2442.726814
#  dtype: float64,
#  CoA    2435.521054
#  dtype: float64,
#  CoA    2428.33705
#  dtype: float64,
#  CoA    2421.174735
#  dtype: float64,
#  CoA    2414.034043
#  dtype: float64,
#  CoA    2406.914909
#  dtype: float64,
#  CoA    2399.817269
#  dtype: float64,
#  CoA    2392.741056
#  dtype: float64,
#  CoA    2385.686207
#  dtype: float64,
#  CoA    2378.652658
#  dtype: float64,
#  CoA    2371.640343
#  dtype: float64,
#  CoA    2364.649198
#  dtype: float64,
#  CoA    2357.67916
#  dtype: float64,
#  CoA    2350.730166
#  dtype: float64,
#  CoA    2343.80215
#  dtype: float64,
#  CoA    2336.895051
#  dtype: float64,
#  CoA    2330.008805
#  dtype: float64,
# ...

# %%
#mean square error 
sum_mean = 0
y = np.array(y_test)
for i in range(len(y_pred)):
    sum_mean+=(y[i]-y_pred[i])**2
mse=sum_mean/len(y_pred)
print ("MSE:",mse)
# Out:
# MSE: [97.25236269]

# %%
#Root Mean Squared Error
rmse = np.sqrt(mse)
rmse
# Out:
# array([9.86166125])

# %%
n = len(training_errors)
training, = plt.plot(range(n), training_errors, label="Training Error")
plt.legend(handles=[training])
plt.title("Error Plot")
plt.ylabel('Mean Squared Error')
plt.xlabel('Iterations')
plt.show()

# %%
plt.xlabel('CGPA')
plt.ylabel('Chance of Admit ')
plt.title('MY MODEL real vs prediction')
plt.scatter(x_test,y_test)
plt.scatter(x_test,y_pred)

# %%
from sklearn.linear_model import LinearRegression
x_train=np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
model = LinearRegression()
model.fit(x_train,y_train)
predict = model.predict(x_test)

from sklearn.metrics import mean_squared_error
error = mean_squared_error(y_test,predict)
error
# Out:
# 53.28822595811962

# %%
plt.xlabel('CGPA')
plt.ylabel('Chance of Admit ')
plt.title('Using sklearn real vs prediction')
plt.scatter(x_test,y_test)
plt.scatter(x_test,predict)
